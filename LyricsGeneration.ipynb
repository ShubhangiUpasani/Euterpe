# %%
# https://colab.research.google.com/drive/1s4QEKdJ2139EMtkdWMkYQLUgkeuWkcdI

import numpy as np
import pandas as pd
import os
import pickle
from matplotlib import pyplot as plt
import seaborn as sns
import re

# %%
with open('data/lyrics_genre_MSD_1000chunks.pickle', 'rb') as chunkf:
    df = pickle.load(chunkf)

# %%
df.head()
# Out:
#     analysis_sample_rate  artist_7digitalid  artist_familiarity  \
# 0                22050.0            82186.0            0.602216
# 2                22050.0            30198.0            0.835272
# 3                22050.0            52651.0            0.653299
# 8                22050.0             5232.0            0.532842
# 12               22050.0            23041.0            0.834539
#
#     artist_hotttnesss              artist_id  artist_latitude artist_location  \
# 0            0.349761  b'ARCU2G21187FB4CFA6'         40.20971  b'Neptune, NJ'
# 2            0.741724  b'ARS8GNX1187B9B5141'         41.08419    b'Akron, OH'
# 3            0.482431  b'ARIFAA91187FB37EA6'         62.19845       b'Sweden'
# 8            0.407992  b'ARUK6QK1187FB570EA'              NaN             b''
# 12           0.477311  b'AR6F6I21187FB5A3AA'              NaN             b''
#
#     artist_longitude                              artist_mbid  \
# ...

# %%
# import unicode
allLyrics = df['lyrics'][0:20000]
combo=""
for lyric in allLyrics:
    lyric = str(lyric)
    lyric = re.sub(r'\W+ \n', '', lyric)
    combo = combo+lyric+"\n\n"
    combo = combo.encode().decode('utf-8','ignore')
#     combo = unicode(combo, "utf-8")
#     decode('utf-8', 'ignore')
print(combo)
with open('allLyrics.txt','a') as f:
    f.write(combo)
    f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-73ea705775fb> in <module>
#       6     lyric = re.sub(r'\W+ \n', '', lyric)
#       7     combo = combo+lyric+"\n\n"
# ----> 8     combo = combo.encode().decode('utf-8','ignore')
#       9 #     combo = unicode(combo, "utf-8")
#      10 #     decode('utf-8', 'ignore')
#
# KeyboardInterrupt:

# %%
allLyrics = df['lyrics'][0:10]
combo=""
for lyric in allLyrics:
    lyric = str(lyric)
    lyric = re.sub(r'\W+ \n', '', lyric)
    combo = combo+lyric
    with open('allLyrics1.txt','a') as f:
        f.write(lyric)
        f.write("\n")
        f.write("\n")
        f.write("\n")
        f.close()
